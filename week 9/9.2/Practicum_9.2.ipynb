# %% [markdown]
# # Frequente item sets
# Frequent Itemsets met A-Priori-algoritme

# %%
import pyodbc
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # Database connectie

# %%
# database name
DB = {
    'servername': '(local)\\SQLEXPRESS',
    'database': 'DEDS_DataWarehouse'}

# %%
export_conn = pyodbc.connect('DRIVER={SQL Server};SERVER=' + DB['servername'] + ';DATABASE=' + DB['database'] + ';Trusted_Connection=yes')


# Create a cursor from the connection
export_cursor = export_conn.cursor()

# check if connection is successful, else throw an error
if export_conn:
    print("Connection with database is established")
else:
    print("Connection with database is not established")
    raise Exception("Connection with database is not established")
# Out:
# Connection with database is established

# %% [markdown]
# ## Tabellen inlezen
# Great Outdoors wil graag weten welke producten vaak samen gekocht worden door klanten.
# Hiervoor hebben we informatie uit de volgende tabellen nodig:
# - product
# - order_details

# %%
product_query = "SELECT * FROM Product"

product_result = export_cursor.execute(product_query)
product_fetch = product_result.fetchall()
product_columns = [column[0] for column in product_result.description]
product = pd.DataFrame.from_records(product_fetch, columns=product_columns)

# Dropping current_value and last_updated columns
product = product.drop(columns=['CURRENT_VALUE', 'LAST_UPDATED'])

product
# Out:
#      PRODUCT_SK  PRODUCT_number      PRODUCT_name_product  \
# 0             1               1       TrailChef Water Bag
# 1             2              10        TrailChef Utensils
# 2             3             100        Insect Bite Relief
# 3             4             101     Hailstorm Steel Irons
# 4             5             102  Hailstorm Titanium Irons
# ..          ...             ...                       ...
# 110         111              95                Sun Shield
# 111         112              96        Compact Relief Kit
# 112         113              97  Deluxe Family Relief Kit
# 113         114              98           Calamine Relief
# 114         115              99               Aloe Relief
#
#                        PRODUCT_description_description PRODUCT_image_image  \
# 0    Lightweight, collapsible bag to carry liquids ...       P01CE1CG1.jpg
# 1    Spoon, fork and knife set made of a light yet ...       P10CE1CG1.jpg
# 2    The Insect Bite Relief helps the itching and s...     P100OP4FA17.jpg
# 3    Iron is 17-4 stainless steel.  Shafts are grap...     P101GE5IR18.jpg
# 4    Made entirely of pure titanium. The ultimate i...     P102GE5IR18.jpg
# ..                                                 ...                 ...
# 110  PABA free sunscreen, SPF 30, poison oak and iv...      P91OP4SS16.jpg
# 111  A personal first aid kit is recommended for ev...      P96OP4FA17.jpg
# 112  A complete medical kit suitable for families w...      P96OP4FA17.jpg
# 113  Use the Calamine Relief for allergic skin reac...      P98OP4FA17.jpg
# 114  Perfect for minor burns and sunburn, the aloe ...      P99OP4FA17.jpg
#
#     PRODUCT_INTRODUCTION_DATE_introduced PRODUCT_PRODUCTION_COST_cost  \
# 0                             2011-02-15                       4.0000
# 1                             2011-02-15                      10.0000
# 2                             2011-02-15                       3.0000
# 3                             2019-12-15                     305.5400
# 4                             2019-10-12                     380.9500
# ..                                   ...                          ...
# 110                           2011-02-15                       3.0000
# 111                           2011-02-15                      16.4300
# 112                           2013-05-03                      25.0000
# 113                           2011-02-15                       3.0000
# 114                           2011-02-15                       2.0000
#
#     PRODUCT_MARGIN_margin PRODUCT_LANGUAGE_language  \
# 0                  0.3300                        EN
# 1                  0.4000                        EN
# 2                  0.5000                        EN
# 3                  0.4300                        EN
# 4                  0.5100                        EN
# ..                    ...                       ...
# 110                0.5000                        EN
# 111                0.2800                        EN
# 112                0.2800                        EN
# 113                0.5000                        EN
# 114                0.6000                        EN
#
#     PRODUCT_MINIMUM_SALE_PRICE_minPrice PRODUCT_PRODUCT_LINE_code  \
# 0                                4.3300                         1
# 1                               10.4000                         1
# 2                                3.5000                         4
# 3                              305.9700                         5
# 4                              381.4600                         5
# ..                                  ...                       ...
# 110                              3.5000                         4
# 111                             16.7100                         4
# 112                             25.2800                         4
# 113                              3.5000                         4
# 114                              2.6000                         4
#
#     PRODUCT_PRODUCT_LINE_code_en PRODUCT_PRODUCT_TYPE_code  \
# 0              Camping Equipment                         1
# 1              Camping Equipment                         1
# 2             Outdoor Protection                        17
# 3                 Golf Equipment                        18
# 4                 Golf Equipment                        18
# ..                           ...                       ...
# 110           Outdoor Protection                        16
# 111           Outdoor Protection                        17
# 112           Outdoor Protection                        17
# 113           Outdoor Protection                        17
# 114           Outdoor Protection                        17
#
#     PRODUCT_PRODUCT_TYPE_code_en
# 0                   Cooking Gear
# 1                   Cooking Gear
# 2                      First Aid
# 3                          Irons
# 4                          Irons
# ..                           ...
# 110                    Sunscreen
# 111                    First Aid
# 112                    First Aid
# 113                    First Aid
# 114                    First Aid
#
# [115 rows x 14 columns]

# %%
order_details_query = "SELECT * FROM Order_details"

order_details_result = export_cursor.execute(order_details_query)
order_details_fetch = order_details_result.fetchall()
order_details_columns = [column[0] for column in order_details_result.description]
order_details = pd.DataFrame.from_records(order_details_fetch, columns=order_details_columns)

# Dropping current_value and last_updated columns
order_details = order_details.drop(columns=['CURRENT_VALUE', 'LAST_UPDATED'])

order_details
# Out:
#        ORDER_DETAILS_SK  ORDER_DETAILS_code  ORDER_DETAILS_QUANTITY_quantity  \
# 0                     1              100000                               16
# 1                     2              100001                               20
# 2                     3              100002                               24
# 3                     4              100003                               18
# 4                     5              100004                               20
# ...                 ...                 ...                              ...
# 43058             43059               99995                              146
# 43059             43060               99996                              172
# 43060             43061               99997                              192
# 43061             43062               99998                              192
# 43062             43063               99999                               22
#
#       ORDER_DETAILS_TOTAL_COST_total ORDER_DETAILS_TOTAL_MARGIN_margin  \
# 0                           257.6000                          360.6400
# 1                           322.0000                          450.8000
# 2                           386.4000                          540.9600
# 3                           289.8000                          405.7200
# 4                           322.0000                          450.8000
# ...                              ...                               ...
# 43058                       402.9600                          810.3000
# 43059                       474.7200                          954.6000
# 43060                       529.9200                         1065.6000
# 43061                       529.9200                         1065.6000
# 43062                       354.2000                          495.8800
#
#        ORDER_DETAILS_ORDER_NUMBER_order  ORDER_DETAILS_PRODUCT_NUMBER_product  \
# 0                                  4405                                   112
# 1                                  5008                                   112
# 2                                  4394                                   112
# 3                                  4396                                   112
# 4                                  4382                                   112
# ...                                 ...                                   ...
# 43058                              4402                                   111
# 43059                              4400                                   111
# 43060                              5148                                   111
# 43061                              4384                                   111
# 43062                              4383                                   112
#
#        ORDER_DETAILS_UNIT_ID_unit
# 0                               1
# 1                               2
# 2                               3
# 3                               4
# 4                               5
# ...                           ...
# 43058                       43059
# 43059                       43060
# 43060                       43061
# 43061                       43062
# 43062                       43063
#
# [43063 rows x 8 columns]

# %% [markdown]
# ## Database connectie sluiten

# %%
export_cursor.close()
export_conn.close()

# %% [markdown]
# ## Data samenvoegen

# %%
combined_data = pd.merge(order_details, product, left_on='ORDER_DETAILS_PRODUCT_NUMBER_product', right_on='PRODUCT_SK')

# dropping all sk columns
sk_columns = combined_data.filter(like='SK').columns
combined_data.drop(columns=sk_columns, inplace=True)

combined_data
# Out:
#        ORDER_DETAILS_code  ORDER_DETAILS_QUANTITY_quantity  \
# 0                  100000                               16
# 1                  100001                               20
# 2                  100002                               24
# 3                  100003                               18
# 4                  100004                               20
# ...                   ...                              ...
# 43058               99995                              146
# 43059               99996                              172
# 43060               99997                              192
# 43061               99998                              192
# 43062               99999                               22
#
#       ORDER_DETAILS_TOTAL_COST_total ORDER_DETAILS_TOTAL_MARGIN_margin  \
# 0                           257.6000                          360.6400
# 1                           322.0000                          450.8000
# 2                           386.4000                          540.9600
# 3                           289.8000                          405.7200
# 4                           322.0000                          450.8000
# ...                              ...                               ...
# 43058                       402.9600                          810.3000
# 43059                       474.7200                          954.6000
# 43060                       529.9200                         1065.6000
# 43061                       529.9200                         1065.6000
# 43062                       354.2000                          495.8800
#
#        ORDER_DETAILS_ORDER_NUMBER_order  ORDER_DETAILS_PRODUCT_NUMBER_product  \
# 0                                  4405                                   112
# 1                                  5008                                   112
# 2                                  4394                                   112
# 3                                  4396                                   112
# 4                                  4382                                   112
# ...                                 ...                                   ...
# 43058                              4402                                   111
# 43059                              4400                                   111
# 43060                              5148                                   111
# 43061                              4384                                   111
# 43062                              4383                                   112
#
#        ORDER_DETAILS_UNIT_ID_unit  PRODUCT_number PRODUCT_name_product  \
# 0                               1              96   Compact Relief Kit
# 1                               2              96   Compact Relief Kit
# 2                               3              96   Compact Relief Kit
# 3                               4              96   Compact Relief Kit
# 4                               5              96   Compact Relief Kit
# ...                           ...             ...                  ...
# 43058                       43059              95           Sun Shield
# 43059                       43060              95           Sun Shield
# 43060                       43061              95           Sun Shield
# 43061                       43062              95           Sun Shield
# 43062                       43063              96   Compact Relief Kit
#
#                          PRODUCT_description_description PRODUCT_image_image  \
# 0      A personal first aid kit is recommended for ev...      P96OP4FA17.jpg
# 1      A personal first aid kit is recommended for ev...      P96OP4FA17.jpg
# 2      A personal first aid kit is recommended for ev...      P96OP4FA17.jpg
# 3      A personal first aid kit is recommended for ev...      P96OP4FA17.jpg
# 4      A personal first aid kit is recommended for ev...      P96OP4FA17.jpg
# ...                                                  ...                 ...
# 43058  PABA free sunscreen, SPF 30, poison oak and iv...      P91OP4SS16.jpg
# 43059  PABA free sunscreen, SPF 30, poison oak and iv...      P91OP4SS16.jpg
# 43060  PABA free sunscreen, SPF 30, poison oak and iv...      P91OP4SS16.jpg
# 43061  PABA free sunscreen, SPF 30, poison oak and iv...      P91OP4SS16.jpg
# 43062  A personal first aid kit is recommended for ev...      P96OP4FA17.jpg
#
#       PRODUCT_INTRODUCTION_DATE_introduced PRODUCT_PRODUCTION_COST_cost  \
# 0                               2011-02-15                      16.4300
# 1                               2011-02-15                      16.4300
# 2                               2011-02-15                      16.4300
# 3                               2011-02-15                      16.4300
# 4                               2011-02-15                      16.4300
# ...                                    ...                          ...
# 43058                           2011-02-15                       3.0000
# 43059                           2011-02-15                       3.0000
# 43060                           2011-02-15                       3.0000
# 43061                           2011-02-15                       3.0000
# 43062                           2011-02-15                      16.4300
#
#       PRODUCT_MARGIN_margin PRODUCT_LANGUAGE_language  \
# 0                    0.2800                        EN
# 1                    0.2800                        EN
# 2                    0.2800                        EN
# 3                    0.2800                        EN
# 4                    0.2800                        EN
# ...                     ...                       ...
# 43058                0.5000                        EN
# 43059                0.5000                        EN
# 43060                0.5000                        EN
# 43061                0.5000                        EN
# 43062                0.2800                        EN
#
#       PRODUCT_MINIMUM_SALE_PRICE_minPrice PRODUCT_PRODUCT_LINE_code  \
# 0                                 16.7100                         4
# 1                                 16.7100                         4
# 2                                 16.7100                         4
# 3                                 16.7100                         4
# 4                                 16.7100                         4
# ...                                   ...                       ...
# 43058                              3.5000                         4
# 43059                              3.5000                         4
# 43060                              3.5000                         4
# 43061                              3.5000                         4
# 43062                             16.7100                         4
#
#       PRODUCT_PRODUCT_LINE_code_en PRODUCT_PRODUCT_TYPE_code  \
# 0               Outdoor Protection                        17
# 1               Outdoor Protection                        17
# 2               Outdoor Protection                        17
# 3               Outdoor Protection                        17
# 4               Outdoor Protection                        17
# ...                            ...                       ...
# 43058           Outdoor Protection                        16
# 43059           Outdoor Protection                        16
# 43060           Outdoor Protection                        16
# 43061           Outdoor Protection                        16
# 43062           Outdoor Protection                        17
#
#       PRODUCT_PRODUCT_TYPE_code_en
# 0                        First Aid
# 1                        First Aid
# 2                        First Aid
# 3                        First Aid
# 4                        First Aid
# ...                            ...
# 43058                    Sunscreen
# 43059                    Sunscreen
# 43060                    Sunscreen
# 43061                    Sunscreen
# 43062                    First Aid
#
# [43063 rows x 20 columns]

# %% [markdown]
# ## Data voorbereiden

# %%
# dropping all columns except ORDER_DETAILS_ORDER_NUMBER_order and PRODUCT_name_product
combined_data = combined_data[['ORDER_DETAILS_ORDER_NUMBER_order', 'PRODUCT_name_product']]

# Group the data by 'ORDER_DETAILS_ORDER_NUMBER_order'
grouped_data = combined_data.groupby('ORDER_DETAILS_ORDER_NUMBER_order')

# Apply dummy encoding to the 'PRODUCT_name_product' column
dummy_data = pd.get_dummies(combined_data['PRODUCT_name_product'])

# dropping the 'PRODUCT_name_product' column
combined_data = combined_data.drop(columns=['PRODUCT_name_product'])

# Join the dummy encoded DataFrame back to the original DataFrame
combined_data_encoded = pd.concat([combined_data, dummy_data], axis=1)

# Group by 'ORDER_DETAILS_ORDER_NUMBER_order' again and sum the dummy columns. This is needed to combine multiple rows for the same order into one row
final_data = combined_data_encoded.groupby('ORDER_DETAILS_ORDER_NUMBER_order').sum()

# Convert the dummy columns to boolean
final_data = final_data.astype(bool)

final_data
# Out:
#                                   Aloe Relief  Bear Edge  Bear Survival Edge  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                       False      False               False
# 2                                       False      False               False
# 3                                       False      False               False
# 4                                        True      False               False
# 5                                        True      False               False
# ...                                       ...        ...                 ...
# 5356                                    False      False               False
# 5357                                    False      False               False
# 5358                                     True      False               False
# 5359                                    False      False               False
# 5360                                    False      False               False
#
#                                   Blue Steel Max Putter  Blue Steel Putter  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                                 False              False
# 2                                                 False              False
# 3                                                 False              False
# 4                                                 False              False
# 5                                                 False              False
# ...                                                 ...                ...
# 5356                                              False              False
# 5357                                              False              False
# 5358                                              False              False
# 5359                                              False              False
# 5360                                              False              False
#
#                                   BugShield Extreme  BugShield Lotion  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                              True             False
# 2                                             False             False
# 3                                             False             False
# 4                                             False             False
# 5                                             False             False
# ...                                             ...               ...
# 5356                                          False             False
# 5357                                           True             False
# 5358                                          False             False
# 5359                                          False             False
# 5360                                          False             False
#
#                                   BugShield Lotion Lite  BugShield Natural  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                                 False              False
# 2                                                 False              False
# 3                                                 False              False
# 4                                                 False              False
# 5                                                 False              False
# ...                                                 ...                ...
# 5356                                              False              False
# 5357                                              False              False
# 5358                                              False              False
# 5359                                              False              False
# 5360                                               True              False
#
#                                   BugShield Spray  ...  TrailChef Canteen  \
# ORDER_DETAILS_ORDER_NUMBER_order                   ...
# 1                                           False  ...               True
# 2                                           False  ...              False
# 3                                           False  ...               True
# 4                                           False  ...              False
# 5                                           False  ...              False
# ...                                           ...  ...                ...
# 5356                                        False  ...              False
# 5357                                        False  ...              False
# 5358                                        False  ...              False
# 5359                                        False  ...               True
# 5360                                        False  ...              False
#
#                                   TrailChef Cook Set  TrailChef Cup  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                              False          False
# 2                                              False          False
# 3                                              False          False
# 4                                              False          False
# 5                                              False          False
# ...                                              ...            ...
# 5356                                           False          False
# 5357                                            True           True
# 5358                                           False          False
# 5359                                           False          False
# 5360                                            True          False
#
#                                   TrailChef Deluxe Cook Set  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                                     False
# 2                                                     False
# 3                                                     False
# 4                                                     False
# 5                                                     False
# ...                                                     ...
# 5356                                                  False
# 5357                                                  False
# 5358                                                   True
# 5359                                                  False
# 5360                                                  False
#
#                                   TrailChef Double Flame  TrailChef Kettle  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                                  False             False
# 2                                                  False             False
# 3                                                  False             False
# 4                                                   True             False
# 5                                                   True             False
# ...                                                  ...               ...
# 5356                                               False             False
# 5357                                               False             False
# 5358                                               False             False
# 5359                                                True             False
# 5360                                                True             False
#
#                                   TrailChef Kitchen Kit  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# 5                                                 False
# ...                                                 ...
# 5356                                              False
# 5357                                              False
# 5358                                               True
# 5359                                              False
# 5360                                               True
#
#                                   TrailChef Single Flame  TrailChef Utensils  \
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                                  False               False
# 2                                                  False               False
# 3                                                  False               False
# 4                                                  False               False
# 5                                                  False               False
# ...                                                  ...                 ...
# 5356                                               False               False
# 5357                                                True                True
# 5358                                               False               False
# 5359                                               False                True
# 5360                                               False               False
#
#                                   TrailChef Water Bag
# ORDER_DETAILS_ORDER_NUMBER_order
# 1                                               False
# 2                                                True
# 3                                               False
# 4                                               False
# 5                                               False
# ...                                               ...
# 5356                                            False
# 5357                                            False
# 5358                                            False
# 5359                                             True
# 5360                                             True
#
# [5360 rows x 115 columns]

# %% [markdown]
# ## A-Priori-algoritme
# Support is de relatieve frequentie waarmee de regels opduiken. Als een product in 20% van de transacties voorkomt, is de support 0.2.
#
# Confidence is een maat voor de betrouwbaarheid van de regel. Een confidence van 0.5 betekent dat in 50% van de gevallen waarin {A} en {B} werden gekocht, de aankoop ook {C} omvatte.
#
# Lift is de verhouding tussen de waargenomen support en de verwachte support als A en C onafhankelijk zouden zijn. De vuistregel is dat een liftwaarde dicht bij 1 betekent dat de regels volledig onafhankelijk waren.
#
# Rules zijn het resultaat van het algoritme voor associatieregels. Dit zijn de regels die frequent werden gevonden in de gegevens.
#
# Antecedents zijn de items die worden gekocht ({A} -> {B}, A is de antecedent).
# Consequents zijn de items die samen met het antecedent worden gekocht ({A} -> {B}, B is de consequent). Consequents zijn dus de voorwaarden die volgen op de antecedenten, de voorspellingen.

# %%
# Define the support and confidence values to try
support_values = [0.2, 0.1, 0.05, 0.01]
confidence_values = [0.3, 0.4, 0.5, 0.6, 0.7]

# Create a list to store the DataFrames
rules_list = []

frequent_itemsets_list = []

# Iterate over all combinations of support and confidence values
for support in support_values:
    for confidence in confidence_values:
        # Generate frequent itemsets with the current support value
        frequent_itemsets = apriori(final_data, min_support=support, use_colnames=True)
        
        # if the frequent_itemsets DataFrame is empty, skip this iteration.
        if frequent_itemsets.empty:
            continue
            
        # Append the frequent_itemsets DataFrame to the list
        frequent_itemsets_list.append(frequent_itemsets)
        
        # Generate the rules with the current confidence value. Filtering out rules where the confidence of the model is less than the confidence value
        # Rules refer to the relationship between the products
        rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=confidence)
        
        # Add the support and confidence values to the rules DataFrame
        rules['Min Support'] = support
        rules['Min Confidence'] = confidence

        # If the rules DataFrame is empty, skip this iteration.
        if rules.empty:
            continue
            
        # Append the rules DataFrame to the list
        rules_list.append(rules)
             
# Concatenate all the DataFrames in the list into a single DataFrame
apriori_df = pd.concat(rules_list, ignore_index=True)

# moving min confidence and min support to the front
cols = apriori_df.columns.tolist()
cols = cols[-2:] + cols[:-2] # kinda hacky way to move the last two columns to the front but oh well
apriori_df = apriori_df[cols]

apriori_df
# Out:
#      Min Support  Min Confidence  \
# 0           0.01             0.3
# 1           0.01             0.3
# 2           0.01             0.3
# 3           0.01             0.3
# 4           0.01             0.3
# ..           ...             ...
# 131         0.01             0.4
# 132         0.01             0.4
# 133         0.01             0.4
# 134         0.01             0.5
# 135         0.01             0.5
#
#                                            antecedents  \
# 0                              (Blue Steel Max Putter)
# 1                              (Blue Steel Max Putter)
# 2                           (Hailstorm Titanium Irons)
# 3                              (Blue Steel Max Putter)
# 4                       (Hailstorm Titanium Woods Set)
# ..                                                 ...
# 131  (Blue Steel Max Putter, Lady Hailstorm Titaniu...
# 132  (Blue Steel Max Putter, Lady Hailstorm Titaniu...
# 133  (Lady Hailstorm Titanium Irons, Lady Hailstorm...
# 134  (Blue Steel Max Putter, Lady Hailstorm Titaniu...
# 135  (Lady Hailstorm Titanium Irons, Lady Hailstorm...
#
#                              consequents  antecedent support  \
# 0                    (Blue Steel Putter)            0.066791
# 1             (Hailstorm Titanium Irons)            0.066791
# 2                (Blue Steel Max Putter)            0.077985
# 3         (Hailstorm Titanium Woods Set)            0.066791
# 4                (Blue Steel Max Putter)            0.062873
# ..                                   ...                 ...
# 131  (Lady Hailstorm Titanium Woods Set)            0.019590
# 132      (Lady Hailstorm Titanium Irons)            0.022761
# 133              (Blue Steel Max Putter)            0.020336
# 134  (Lady Hailstorm Titanium Woods Set)            0.019590
# 135              (Blue Steel Max Putter)            0.020336
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 0              0.072761  0.020149    0.301676  4.146111  0.015289    1.327806
# 1              0.077985  0.025746    0.385475  4.942931  0.020538    1.500370
# 2              0.066791  0.025746    0.330144  4.942931  0.020538    1.393148
# 3              0.062873  0.022015    0.329609  5.242445  0.017816    1.397881
# 4              0.066791  0.022015    0.350148  5.242445  0.017816    1.436034
# ..                  ...       ...         ...       ...       ...         ...
# 131            0.059142  0.010448    0.533333  9.017876  0.009289    2.016125
# 132            0.054664  0.010448    0.459016  8.397023  0.009204    1.747439
# 133            0.066791  0.010448    0.513761  7.692071  0.009090    1.919241
# 134            0.059142  0.010448    0.533333  9.017876  0.009289    2.016125
# 135            0.066791  0.010448    0.513761  7.692071  0.009090    1.919241
#
#      zhangs_metric
# 0         0.813119
# 1         0.854783
# 2         0.865160
# 3         0.867168
# 4         0.863543
# ..             ...
# 131       0.906874
# 132       0.901428
# 133       0.888055
# 134       0.906874
# 135       0.888055
#
# [136 rows x 12 columns]

# %%
itemsets_df = pd.concat(frequent_itemsets_list, ignore_index=True)

# filtering for a support of at least 0.1
frequent_itemsets_df = itemsets_df[itemsets_df['support'] >= 0.1]
infrequent_itemsets_df = itemsets_df[itemsets_df['support'] < 0.1]

# %%
# displaying frequent itemsets
frequent_itemsets_df
# Out:
#        support                itemsets
# 0     0.106903  (Canyon Mule Carryall)
# 1     0.101119           (Double Edge)
# 2     0.104104        (Sun Shelter 30)
# 3     0.106903  (Canyon Mule Carryall)
# 4     0.101119           (Double Edge)
# 5     0.104104        (Sun Shelter 30)
# 6     0.106903  (Canyon Mule Carryall)
# 7     0.101119           (Double Edge)
# 8     0.104104        (Sun Shelter 30)
# 9     0.106903  (Canyon Mule Carryall)
# 10    0.101119           (Double Edge)
# 11    0.104104        (Sun Shelter 30)
# 12    0.106903  (Canyon Mule Carryall)
# 13    0.101119           (Double Edge)
# 14    0.104104        (Sun Shelter 30)
# 26    0.106903  (Canyon Mule Carryall)
# 38    0.101119           (Double Edge)
# 109   0.104104        (Sun Shelter 30)
# 133   0.106903  (Canyon Mule Carryall)
# 145   0.101119           (Double Edge)
# 216   0.104104        (Sun Shelter 30)
# 240   0.106903  (Canyon Mule Carryall)
# 252   0.101119           (Double Edge)
# 323   0.104104        (Sun Shelter 30)
# 347   0.106903  (Canyon Mule Carryall)
# 359   0.101119           (Double Edge)
# 430   0.104104        (Sun Shelter 30)
# 454   0.106903  (Canyon Mule Carryall)
# 466   0.101119           (Double Edge)
# 537   0.104104        (Sun Shelter 30)
# 561   0.106903  (Canyon Mule Carryall)
# 574   0.101119           (Double Edge)
# 652   0.104104        (Sun Shelter 30)
# 2468  0.106903  (Canyon Mule Carryall)
# 2481  0.101119           (Double Edge)
# 2559  0.104104        (Sun Shelter 30)
# 4375  0.106903  (Canyon Mule Carryall)
# 4388  0.101119           (Double Edge)
# 4466  0.104104        (Sun Shelter 30)
# 6282  0.106903  (Canyon Mule Carryall)
# 6295  0.101119           (Double Edge)
# 6373  0.104104        (Sun Shelter 30)
# 8189  0.106903  (Canyon Mule Carryall)
# 8202  0.101119           (Double Edge)
# 8280  0.104104        (Sun Shelter 30)

# %%
# displaying infrequent itemsets
infrequent_itemsets_df
# Out:
#         support                                           itemsets
# 15     0.057463                                      (Aloe Relief)
# 16     0.082649                                        (Bear Edge)
# 17     0.073507                               (Bear Survival Edge)
# 18     0.066791                            (Blue Steel Max Putter)
# 19     0.072761                                (Blue Steel Putter)
# ...         ...                                                ...
# 10080  0.016978       (TrailChef Water Bag, TrailChef Kitchen Kit)
# 10081  0.014552       (TrailChef Single Flame, TrailChef Utensils)
# 10082  0.012313      (TrailChef Single Flame, TrailChef Water Bag)
# 10083  0.015672          (TrailChef Water Bag, TrailChef Utensils)
# 10084  0.010448  (Blue Steel Max Putter, Lady Hailstorm Titaniu...
#
# [10040 rows x 2 columns]
